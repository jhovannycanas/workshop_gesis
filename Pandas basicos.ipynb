# %%
import numpy as np
import pandas as pd
#permite visualizar los graficos en el cuaderno
# %matplotlib inline

# %% [markdown]
# ## Leer un archivo

# %%
df = pd.read_csv('data/weather.csv')

# %%
df
# Out:
#       MONTH  DAY  TIME  TEMP  PRESSURE
# 0         1    1     1   6.8     10207
# 1         1    1     2   5.8     10214
# 2         1    1     3   5.7     10220
# 3         1    1     4   6.0     10225
# 4         1    1     5   4.5     10230
# 5         1    1     6   2.0     10237
# 6         1    1     7   1.1     10242
# 7         1    1     8   0.7     10245
# 8         1    1     9   0.2     10248
# 9         1    1    10   2.0     10249
# 10        1    1    11   7.2     10245
# 11        1    1    12   7.9     10239
# 12        1    1    13   7.7     10231
# 13        1    1    14   7.2     10225
# 14        1    1    15   5.3     10220
# 15        1    1    16   5.0     10217
# 16        1    1    17   4.9     10205
# 17        1    1    18   4.9     10194
# 18        1    1    19   5.4     10188
# 19        1    1    20   5.7     10183
# 20        1    1    21   5.4     10170
# 21        1    1    22   5.3     10161
# 22        1    1    23   5.4     10146
# 23        1    1    24   5.6     10140
# 24        1    2     1   5.6     10124
# 25        1    2     2   5.6     10119
# 26        1    2     3   5.5     10109
# 27        1    2     4   5.4     10102
# 28        1    2     5   5.3     10093
# 29        1    2     6   5.3     10089
# ...     ...  ...   ...   ...       ...
# 8754     12  365    19   3.9     10354
# 8755     12  365    20   3.6     10354
# 8756     12  365    21   3.5     10352
# 8757     12  365    22   3.5     10348
# 8758     12  365    23   3.6     10344
# 8759     12  365    24   4.0     10340
# 8760     12  366     1   3.9     10338
# 8761     12  366     2   3.6     10336
# 8762     12  366     3   3.4     10333
# 8763     12  366     4   3.2     10331
# 8764     12  366     5   3.0     10328
# 8765     12  366     6   2.9     10326
# 8766     12  366     7   3.2     10324
# 8767     12  366     8   3.4     10324
# 8768     12  366     9   3.4     10324
# 8769     12  366    10   3.3     10321
# 8770     12  366    11   3.9     10317
# 8771     12  366    12   4.5     10307
# 8772     12  366    13   5.0     10301
# 8773     12  366    14   5.2     10295
# 8774     12  366    15   5.1     10288
# 8775     12  366    16   4.6     10286
# 8776     12  366    17   4.1     10284
# 8777     12  366    18   3.7     10277
# 8778     12  366    19   3.5     10271
# 8779     12  366    20   3.5     10265
# 8780     12  366    21   3.4     10258
# 8781     12  366    22   3.0     10253
# 8782     12  366    23   2.8     10246
# 8783     12  366    24   2.8     10239
#
# [8784 rows x 5 columns]

# %%
df.shape
# Out:
# (8784, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 5 columns):
# MONTH       8784 non-null int64
# DAY         8784 non-null int64
# TIME        8784 non-null int64
# TEMP        8784 non-null float64
# PRESSURE    8784 non-null int64
# dtypes: float64(1), int64(4)
# memory usage: 343.2 KB

# %%
df.head(5)
# Out:
#    MONTH  DAY  TIME  TEMP  PRESSURE
# 0      1    1     1   6.8     10207
# 1      1    1     2   5.8     10214
# 2      1    1     3   5.7     10220
# 3      1    1     4   6.0     10225
# 4      1    1     5   4.5     10230

# %%
df.tail(5)
# Out:
#       MONTH  DAY  TIME  TEMP  PRESSURE
# 8779     12  366    20   3.5     10265
# 8780     12  366    21   3.4     10258
# 8781     12  366    22   3.0     10253
# 8782     12  366    23   2.8     10246
# 8783     12  366    24   2.8     10239

# %%
df.describe()
# Out:
#              MONTH          DAY         TIME         TEMP      PRESSURE
# count  8784.000000  8784.000000  8784.000000  8784.000000   8784.000000
# mean      6.513661   183.500000    12.500000    10.768613  10159.254781
# std       3.451430   105.660719     6.922581     6.420003    102.895130
# min       1.000000     1.000000     1.000000    -6.500000   9812.000000
# 25%       4.000000    92.000000     6.750000     6.100000  10102.000000
# 50%       7.000000   183.500000    12.500000    10.200000  10169.000000
# 75%      10.000000   275.000000    18.250000    15.900000  10227.000000
# max      12.000000   366.000000    24.000000    31.700000  10453.000000

# %%
df.mean()
# Out:
# MONTH           6.513661
# DAY           183.500000
# TIME           12.500000
# TEMP           10.768613
# PRESSURE    10159.254781
# dtype: float64

# %%
df.max()
# Out:
# MONTH          12.0
# DAY           366.0
# TIME           24.0
# TEMP           31.7
# PRESSURE    10453.0
# dtype: float64

# %%
df['TEMP']
# Out:
# 0       6.8
# 1       5.8
# 2       5.7
# 3       6.0
# 4       4.5
# 5       2.0
# 6       1.1
# 7       0.7
# 8       0.2
# 9       2.0
# 10      7.2
# 11      7.9
# 12      7.7
# 13      7.2
# 14      5.3
# 15      5.0
# 16      4.9
# 17      4.9
# 18      5.4
# 19      5.7
# 20      5.4
# 21      5.3
# 22      5.4
# 23      5.6
# 24      5.6
# 25      5.6
# 26      5.5
# 27      5.4
# 28      5.3
# 29      5.3
#        ...
# 8754    3.9
# 8755    3.6
# 8756    3.5
# 8757    3.5
# 8758    3.6
# 8759    4.0
# 8760    3.9
# 8761    3.6
# 8762    3.4
# 8763    3.2
# 8764    3.0
# 8765    2.9
# 8766    3.2
# 8767    3.4
# 8768    3.4
# 8769    3.3
# 8770    3.9
# 8771    4.5
# 8772    5.0
# 8773    5.2
# 8774    5.1
# 8775    4.6
# 8776    4.1
# 8777    3.7
# 8778    3.5
# 8779    3.5
# 8780    3.4
# 8781    3.0
# 8782    2.8
# 8783    2.8
# Name: TEMP, Length: 8784, dtype: float64

# %%
df['TEMP'].max()
# Out:
# 31.7

# %%
df['TEMP'].plot()

# %%
df['TEMP'].plot.hist(bins = 50)

# %% [markdown]
# ## seleccionar y filtrar datos

# %%
df['PRESSURE']
# Out:
# 0       10207
# 1       10214
# 2       10220
# 3       10225
# 4       10230
# 5       10237
# 6       10242
# 7       10245
# 8       10248
# 9       10249
# 10      10245
# 11      10239
# 12      10231
# 13      10225
# 14      10220
# 15      10217
# 16      10205
# 17      10194
# 18      10188
# 19      10183
# 20      10170
# 21      10161
# 22      10146
# 23      10140
# 24      10124
# 25      10119
# 26      10109
# 27      10102
# 28      10093
# 29      10089
#         ...
# 8754    10354
# 8755    10354
# 8756    10352
# 8757    10348
# 8758    10344
# 8759    10340
# 8760    10338
# 8761    10336
# 8762    10333
# 8763    10331
# 8764    10328
# 8765    10326
# 8766    10324
# 8767    10324
# 8768    10324
# 8769    10321
# 8770    10317
# 8771    10307
# 8772    10301
# 8773    10295
# 8774    10288
# 8775    10286
# 8776    10284
# 8777    10277
# 8778    10271
# 8779    10265
# 8780    10258
# 8781    10253
# 8782    10246
# 8783    10239
# Name: PRESSURE, Length: 8784, dtype: int64

# %%
df.TEMP YEAR
# Out:
#   File "<ipython-input-19-5a25055c78f6>", line 1
#     df.TEMP YEAR
#                ^
# SyntaxError: invalid syntax

# %%
df[['TEMP', 'PRESSURE']]
# Out:
#       TEMP  PRESSURE
# 0      6.8     10207
# 1      5.8     10214
# 2      5.7     10220
# 3      6.0     10225
# 4      4.5     10230
# 5      2.0     10237
# 6      1.1     10242
# 7      0.7     10245
# 8      0.2     10248
# 9      2.0     10249
# 10     7.2     10245
# 11     7.9     10239
# 12     7.7     10231
# 13     7.2     10225
# 14     5.3     10220
# 15     5.0     10217
# 16     4.9     10205
# 17     4.9     10194
# 18     5.4     10188
# 19     5.7     10183
# 20     5.4     10170
# 21     5.3     10161
# 22     5.4     10146
# 23     5.6     10140
# 24     5.6     10124
# 25     5.6     10119
# 26     5.5     10109
# 27     5.4     10102
# 28     5.3     10093
# 29     5.3     10089
# ...    ...       ...
# 8754   3.9     10354
# 8755   3.6     10354
# 8756   3.5     10352
# 8757   3.5     10348
# 8758   3.6     10344
# 8759   4.0     10340
# 8760   3.9     10338
# 8761   3.6     10336
# 8762   3.4     10333
# 8763   3.2     10331
# 8764   3.0     10328
# 8765   2.9     10326
# 8766   3.2     10324
# 8767   3.4     10324
# 8768   3.4     10324
# 8769   3.3     10321
# 8770   3.9     10317
# 8771   4.5     10307
# 8772   5.0     10301
# 8773   5.2     10295
# 8774   5.1     10288
# 8775   4.6     10286
# 8776   4.1     10284
# 8777   3.7     10277
# 8778   3.5     10271
# 8779   3.5     10265
# 8780   3.4     10258
# 8781   3.0     10253
# 8782   2.8     10246
# 8783   2.8     10239
#
# [8784 rows x 2 columns]

# %% [markdown]
# ### seleccionar solo un elemento

# %%
df['PRESSURE'][5]
# Out:
# 10237

# %%
df.columns
# Out:
# Index(['MONTH', 'DAY', 'TIME', 'TEMP', 'PRESSURE'], dtype='object')

# %%
df2 = df['TEMP'][[1,2,5]]

# %%
df2
# Out:
# 1    5.8
# 2    5.7
# 5    2.0
# Name: TEMP, dtype: float64

# %%
df[2:4]
# Out:
#    MONTH  DAY  TIME  TEMP  PRESSURE
# 2      1    1     3   5.7     10220
# 3      1    1     4   6.0     10225

# %%
df[['TEMP', 'PRESSURE']][2:4]
# Out:
#    TEMP  PRESSURE
# 2   5.7     10220
# 3   6.0     10225

# %% [markdown]
# ### loc y iloc

# %%
estudiantes = pd.DataFrame([[3.4,3.6] , [4.4,3.9] , [2.4,4.6] , [3.1,3.0], [4.4,3.8]], columns = ['examen 1', 'examen 2'], index = ['jose', 'maria', 'pablo', 'raul', 'luisa'] )

# %%
estudiantes
# Out:
#        examen 1  examen 2
# jose        3.4       3.6
# maria       4.4       3.9
# pablo       2.4       4.6
# raul        3.1       3.0
# luisa       4.4       3.8

# %%
estudiantes['PROMEDIO'] = 0

# %%
estudiantes
# Out:
#        examen 1  examen 2  PROMEDIO
# jose        3.4       3.6         0
# maria       4.4       3.9         0
# pablo       2.4       4.6         0
# raul        3.1       3.0         0
# luisa       4.4       3.8         0

# %%
del estudiantes['PROMEDIO']

# %%
estudiantes
# Out:
#        examen 1  examen 2
# jose        3.4       3.6
# maria       4.4       3.9
# pablo       2.4       4.6
# raul        3.1       3.0
# luisa       4.4       3.8

# %%
estudiantes.drop(columns='PROMEDIO', inplace=True)

# %%
estudiantes
# Out:
#        examen 1  examen 2
# jose        3.4       3.6
# maria       4.4       3.9
# pablo       2.4       4.6
# raul        3.1       3.0
# luisa       4.4       3.8

# %%
estudiantes1
# Out:
#        examen 1  examen 2
# jose        3.4       3.6
# maria       4.4       3.9
# pablo       2.4       4.6
# raul        3.1       3.0
# luisa       4.4       3.8

# %%
estudiantes

# %% [markdown]
# pemrite obtener los datos por filas

# %%
estudiantes.loc['maria']
# Out:
# examen 1    4.4
# examen 2    3.9
# Name: maria, dtype: float64

# %%
estudiantes.loc[['maria', 'jose']]
# Out:
#        examen 1  examen 2
# maria       4.4       3.9
# jose        3.4       3.6

# %% [markdown]
# saber la nota de maria en el segundo examen

# %%
estudiantes.loc['maria', 'examen 2']
# Out:
# 3.9

# %% [markdown]
# haciendo los mismo con columnas

# %%
estudiantes['examen 2']['maria']
# Out:
# 3.9

# %%
estudiantes.loc['maria':'raul', ['examen 2', 'examen 1']]
# Out:
#        examen 2  examen 1
# maria       3.9       4.4
# pablo       4.6       2.4
# raul        3.0       3.1

# %% [markdown]
# para obtener filas por pocision

# %%
estudiantes.iloc[[0,2]]
# Out:
#        examen 1  examen 2
# jose        3.4       3.6
# pablo       2.4       4.6

# %% [markdown]
# seleccionando las columnas

# %%
estudiantes.iloc[[0,2], 1:]
# Out:
#        examen 2
# jose        3.6
# pablo       4.6

# %% [markdown]
# seleccionar todas las filas y una columna

# %%
estudiantes.iloc[:, 1]
# Out:
# jose     3.6
# maria    3.9
# pablo    4.6
# raul     3.0
# luisa    3.8
# Name: examen 2, dtype: float64

# %% [markdown]
# ### filtrar

# %%
estudiantes[estudiantes == 3.4]
# Out:
#        examen 1  examen 2
# jose        3.4       NaN
# maria       NaN       NaN
# pablo       NaN       NaN
# raul        NaN       NaN
# luisa       NaN       NaN

# %%
estudiantes['examen 1'] +=0.5

# %%
estudiantes
# Out:
#        examen 1  examen 2
# jose        3.9       3.6
# maria       4.9       3.9
# pablo       2.9       4.6
# raul        3.6       3.0
# luisa       4.9       3.8

# %%
estudiantesbuenos = estudiantes[estudiantes['examen 1'] < 3.5]

# %%
estudiantesbuenos
# Out:
#        examen 1  examen 2
# pablo       2.9       4.6

# %%
estudiantes[estudiantes['examen 1'] == "mal"] = 3

# %%
estudiantes

# %%
estudiantes[estudiantes['examen 1'] == "bien"] = 4.2

# %%
estudiantes.sort_index()
# Out:
#        examen 1  examen 2
# jose        3.9       3.6
# luisa       4.9       3.8
# maria       4.9       3.9
# pablo       2.9       4.6
# raul        3.6       3.0

# %%
estudiantes.sort_values(by = 'examen 2')
# Out:
#        examen 1  examen 2
# raul        3.6       3.0
# jose        3.9       3.6
# luisa       4.9       3.8
# maria       4.9       3.9
# pablo       2.9       4.6

# %%
estudiantes.sort_values(by = ['examen 1', 'examen 2'])
# Out:
#        examen 1  examen 2
# pablo       2.9       4.6
# raul        3.6       3.0
# jose        3.9       3.6
# luisa       4.9       3.8
# maria       4.9       3.9
